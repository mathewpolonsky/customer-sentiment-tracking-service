# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/sravni_dataset_w_corrected_dates.csv")

# %%
df
# Out:
#       review_id        date  \
# 0       1000087  2025-09-19
# 1        999494  2025-09-18
# 2        999142  2025-09-17
# 3        998516  2025-09-15
# 4        998360  2025-09-15
# ...         ...         ...
# 4783       7470  2011-04-07
# 4784       7049  2011-03-28
# 4785       5221  2011-01-25
# 4786       5053  2011-01-16
# 4787       4966  2011-01-10
#
#                                             review_text              topic  \
# 0     Вклад «Новые деньги» невозможно оформить без п...             Вклады
# 1     В июне 2025 года я порекомендовал премиальную ...    Дебетовые карты
# 2     Мошенниччиские аперации в интересах Ренессанс ...       Обслуживание
# 3     Производил оформление открытия срочного банков...             Вклады
# 4     Купил услугу Газпром Бонус «Премиум» за 2 990 ...    Дебетовые карты
# ...                                                 ...                ...
# 4783  Ужастное обслуживание! Мало того потеряли доку...       Обслуживание
# ...

# %%
df["topic"].value_counts()
# Out:
# topic
# Дебетовые карты               1150
# Обслуживание                   703
# Кредиты наличными              611
# Кредитные карты                611
# Вклады                         469
# Дистанционное обслуживание     366
# Другие услуги                  365
# Ипотека                        225
# Автокредиты                    113
# Рефинансирование кредитов       84
# Рефинансирование ипотеки        27
# Обмен валют                     26
# Мобильное приложение            18
# РКО                             11
# Денежные переводы                4
# Условия                          3
# Эквайринг                        1
# Кредитование бизнеса             1
# Name: count, dtype: int64

# %%
df.groupby("topic")["subtopic"].value_counts()
# Out:
# topic              subtopic
# Автокредиты        «На автомобиль»                         4
# Вклады             «Копить»                               47
#                    «Накопительный»                        43
#                    «Управляй процентом»                   20
#                    «Управлять»                            19
#                    «Накопительный счёт»                   10
#                    «Трать и копи»                          9
#                    «Ваш успех»                             7
#                    «Ежедневный процент»                    4
#                    «В Плюсе (% в конце срока) »            2
#                    «Копить (% в конце срока)»              2
#                    «Новые деньги»                          2
#                    «В Плюсе»                               1
#                    «Ваш успех (Хит сезона)»                1
#                    «Ваш успех »                            1
# ...

# %%
df["review_text"].sample(5).values
# Out:
# array(['Граждане подумайте семь раз, прежде чем идти на обслуживание в этот банк. Да, сначала все супер. Учтивые девочки, которые сами приедут к вам на работу. Все расскажут, покажут. Как с этим ьанком супер и вы ведетесь на обслуживание, проценты на остаток и т. П. Но получив карточку начинается реальность. Активировать домашний банк, вдумайтесь, необходимо банку 48 часов. 2-Е суток. Это как? Зачем. Все уже давно автоматизировано. Вышел с картой и все. Уже все подключено. Нет. 48 Часов и усе. А чтобы найти офис, пол города изколесишь. Капец обслуживание. Мечты сбываются.\nНо это не все. Выпустив основную карту и второстепенную, вторую активировать надо только в офисе. Банкомат ее нафиг посылает и владельца вместе с ней.\nВот такой суперский ГАЗПРОМБАНК. С ним сбудутся все ваши мечты. Потр. С беготней.',
# ...
