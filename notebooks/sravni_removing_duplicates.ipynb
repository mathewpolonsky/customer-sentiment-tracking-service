# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/sravni_ru/sravni_dataset_w_corrected_dates_and_sentiment.csv")
df
# Out:
#       review_id        date  \
# 0       1000087  2025-09-19
# 1        999494  2025-09-18
# 2        999142  2025-09-17
# 3        998516  2025-09-15
# 4        998360  2025-09-15
# ...         ...         ...
# 4783       7470  2011-04-07
# 4784       7049  2011-03-28
# 4785       5221  2011-01-25
# 4786       5053  2011-01-16
# 4787       4966  2011-01-10
#
#                                             review_text              topic  \
# 0     Вклад «Новые деньги» невозможно оформить без п...             Вклады
# 1     В июне 2025 года я порекомендовал премиальную ...    Дебетовые карты
# 2     Мошенниччиские аперации в интересах Ренессанс ...       Обслуживание
# 3     Производил оформление открытия срочного банков...             Вклады
# 4     Купил услугу Газпром Бонус «Премиум» за 2 990 ...    Дебетовые карты
# ...                                                 ...                ...
# 4783  Ужастное обслуживание! Мало того потеряли доку...       Обслуживание
# ...

# %%
len(df.review_id.unique())
# Out:
# 4778

# %%
len(df['review_id'])
# Out:
# 4788

# %%
df.drop_duplicates(subset=['review_id'], keep='first', inplace=True)

# %%
df.sort_values(by='date', ascending=False, inplace=True)

# %%
df
# Out:
#       review_id        date  \
# 0       1000087  2025-09-19
# 1        999494  2025-09-18
# 2        999142  2025-09-17
# 4        998360  2025-09-15
# 3        998516  2025-09-15
# ...         ...         ...
# 4783       7470  2011-04-07
# 4784       7049  2011-03-28
# 4785       5221  2011-01-25
# 4786       5053  2011-01-16
# 4787       4966  2011-01-10
#
#                                             review_text              topic  \
# 0     Вклад «Новые деньги» невозможно оформить без п...             Вклады
# 1     В июне 2025 года я порекомендовал премиальную ...    Дебетовые карты
# 2     Мошенниччиские аперации в интересах Ренессанс ...       Обслуживание
# 4     Купил услугу Газпром Бонус «Премиум» за 2 990 ...    Дебетовые карты
# 3     Производил оформление открытия срочного банков...             Вклады
# ...                                                 ...                ...
# 4783  Ужастное обслуживание! Мало того потеряли доку...       Обслуживание
# ...

# %%
df.to_csv('../datasets/sravni_ru/sravni_dataset_w_corrected_dates_and_sentiment_wo_duplicates.csv', index=False)
